# %% [markdown]
# <a href="https://colab.research.google.com/github/fju410290051/fin_data/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/fju410290051/fin_data/refs/heads/main/HW_2024-12-10.csv"
df = pd.read_csv(url, index_col=0)
df
# Out:
#                    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# Non-Cumulative
# Company                   Y/M    Quarter   M&A(Y/N)      Month   Currency
# 1216 Uni-President    2024/09          3          Y          9        NTD
# 1216 Uni-President    2024/06          2          Y          6        NTD
# 1216 Uni-President    2024/03          1          Y          3        NTD
# 1216 Uni-President    2023/12          4          Y         12        NTD
# NaN                       NaN        NaN        NaN        NaN        NaN
# Company                   Y/M    Quarter   M&A(Y/N)      Month   Currency
# 1201 Wei Chuan        2024/09          3          Y          9        NTD
# 1201 Wei Chuan        2024/06          2          Y          6        NTD
# 1201 Wei Chuan        2024/03          1          Y          3        NTD
# 1201 Wei Chuan        2023/12          4          Y         12        NTD
# ...
